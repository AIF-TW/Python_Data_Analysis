# %% [markdown]
# # 練習一
#
# 以 numpy 完成 $f(w * x + b)$
#
# w is random numpy array(0 ~ 1)
#
# x is numpy array [0.6, 0.1]
#
# b is numpy array [0.56]
#
# z = w * x + b
#
# ### $f(z) = \frac{1}{1 + {\rm e}^{-z}}$
#
# final output is $f(z)$
